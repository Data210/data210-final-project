# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
#sys.path.insert(1, 'D:\\Sparta\\final_project\\data210-final-project\\Scripts')
from s3 import S3Client
import pandas as pd
import io
import re
import string

# %%
#Config
bucket_name = "data-eng-210-final-project"
client = S3Client()

# %%
import importlib
import talent_transformation_v2 as Talent
importlib.reload(Talent)
import sparta_day_transformation as SpartaDay
importlib.reload(SpartaDay)
import Applicant_cleaning as Applicants
importlib.reload(Applicants)
import academy_transformation as Academy
importlib.reload(Academy)
# Out:
# <module 'academy_transformation' from 'd:\\Sparta\\final_project\\data210-final-project\\Scripts\\academy_transformation.py'>

# %%
df_sparta_day_result, df_sparta_day, df_academy = SpartaDay.getAllData()

# %%
df_spartan, df_course, df_stream, df_trainer, df_behaviour_score = Academy.getAllData()

# %%
df_talent, df_strength_junction, df_weakness_junction, df_tech_junction, df_tech, df_strength, df_weakness = Talent.getAllData()

# %%
df_applicant, df_address ,df_postcode, df_city,  df_recruiter = Applicants.process_locations()

# %%
df_trainer
# Out:
#     trainer_id             trainer
# 0            0        Gregor Gomez
# 1            1          Bruce Lugo
# 2            2       Neil Mccarthy
# 3            3      Rachel Richard
# 4            4        Hamzah Melia
# 5            5       Burhan Milner
# 6            6          Elly Kelly
# 7            7       Trixie Orange
# 8            8        John Sandbox
# 9            9     Edward Reinhart
# 10          10         Lucy Foster
# 11          11     Gina Cartwright
# 12          12        Eshal Brandt
# 13          13     Macey Broughton
# 14          14         Igor Coates
# 15          15  Mohammad Velazquez
# 16          16     Martina Meadows

# %%
df_spartan.name.duplicated(keep=False).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_spartan.name.duplicated(keep=False).sum()
#
# File d:\Sparta\final_project\data210-final-project\env\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
pd.merge(pd.merge(df_spartan,df_course),df_stream)
# Out:
#      spartan_id  course_id  stream_id course_num        date       stream
# 0             0          0          0         20  2019-02-11     Business
# 1             1          0          0         20  2019-02-11     Business
# 2             2          0          0         20  2019-02-11     Business
# 3             3          0          0         20  2019-02-11     Business
# 4             4          0          0         20  2019-02-11     Business
# ..          ...        ...        ...        ...         ...          ...
# 392         392         35          2         29  2019-12-30  Engineering
# 393         393         35          2         29  2019-12-30  Engineering
# 394         394         35          2         29  2019-12-30  Engineering
# 395         395         35          2         29  2019-12-30  Engineering
# 396         396         35          2         29  2019-12-30  Engineering
#
# [397 rows x 6 columns]

# %%
df_talent[df_talent.name.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, date, self_development, geo_flex, financial_support_self, result, course_interest, json_key]
# Index: []

# %%
df_sparta_day[df_sparta_day.name.duplicated(keep=False)]
# Out:
#                  name  psychometrics  presentation       date     academy
# 0  Nicolette Bonehill             47            20 2019-11-19      London
# 2   Shurlocke Cringle             52            21 2019-05-21      London
# 1   Shurlocke Cringle             49            18 2019-01-31  Birmingham
# 4  Nicolette Bonehill             52            23 2019-02-05      London

# %%
df_applicant[df_applicant.name.duplicated(keep=False)]
# Out:
#       applicant_id                name  gender        dob
# 1243          1169  Nicolette Bonehill  Female 1995-04-05  \
# 1566          1497   Shurlocke Cringle    Male 1992-04-16
# 3165          3136   Shurlocke Cringle    Male 1995-11-27
# 3541          3521  Nicolette Bonehill  Female 1999-08-14
#
#                          email      phone_number  uni_id degree invited_date
# 1243  nbonehill1g@hubpages.com  +44-825-679-5108       6    3rd   2019-02-05  \
# 1566      scringle8@uol.com.br               NaN     137    3rd   2019-01-31
# 3165                       NaN  +44-947-829-3817       4    2:2   2019-05-21
# 3541       neebee9@addthis.com  +44-364-359-2606      89    2:1   2019-11-19
#
#       recruiter_id  address_id
# 1243             5        1150
# 1566             8        1473
# 3165             8        3072
# 3541             8        3448

# %%
pd.merge(pd.merge(df_applicant,pd.merge(pd.merge(df_address,df_city),df_postcode)),df_recruiter)
# Out:
#       applicant_id            name  gender        dob
# 0                0  Esme Trusslove  Female 1994-08-04  \
# 1                8    Lay Trosdall    Male 1991-07-05
# 2              344  Bourke Caudrey    Male 1997-12-08
# 3             1196      Jan Horrod  Female 1996-05-15
# 4             1345  Kipp Le Huquet  Female 1991-10-26
# ...            ...             ...     ...        ...
# 4686          4670     Vevay Feirn  Female 1990-09-08
# 4687          4675    Toby Stadden    Male 1990-09-04
# 4688          4681   Arman Boribal    Male 1999-05-07
# 4689          4682    Rip Jordeson    Male 1994-02-16
# 4690          4690   Mercie Groger  Female 1997-05-10
#
#                             email      phone_number  uni_id degree
# 0           etrusslove0@google.es  +44-295-783-0228       0    2:1  \
# 1        ltrosdall8@imageshack.us  +44-572-951-7038       8    NaN
# 2       bcaudrey9k@infoseek.co.jp  +44-981-673-6557      15    2:1
# 3           jhorrod27@blogger.com  +44-452-423-3268      30    2:1
# 4                  kle6c@imdb.com  +44-248-862-0928      30    2:1
# ...                           ...               ...     ...    ...
# 4686         vfeirnb3@twitter.com  +44-432-554-6997     112    1st
# 4687                          NaN  +44-830-894-4930     155    3rd
# 4688   aboribalbe@hugedomains.com               NaN       7    1st
# 4689   rjordesonbf@privacy.gov.au  +44-146-984-9004      62    2:2
# 4690  mgrogerbn@timesonline.co.uk  +44-662-239-4688     111    3rd
#
#      invited_date  recruiter_id  address_id               address
# 0      2019-04-10             1           0  22056 Lerdahl Avenue  \
# 1      2019-04-16             1           8      63 Maywood Place
# 2      2019-04-02             1          12                   NaN
# 3      2019-02-27             1          12                   NaN
# 4      2019-02-14             1          12                   NaN
# ...           ...           ...         ...                   ...
# 4686   2019-09-12             8        4577  0363 Menomonie Plaza
# 4687   2019-09-04             8        4582     8 Wayridge Circle
# 4688   2019-09-04             8        4588     018 Annamark Hill
# 4689   2019-09-25             8        4589     87332 Carey Plaza
# 4690   2019-09-12             8        4597        5 Toban Circle
#
#       postcode_id  city_id        city postcode   recruiter_name
# 0               0        0     Swindon      SN1  Bruno Bellbrook
# 1               8        8    West End     DN36  Bruno Bellbrook
# 2              12       12         NaN      NaN  Bruno Bellbrook
# 3              12       12         NaN      NaN  Bruno Bellbrook
# 4              12       12         NaN      NaN  Bruno Bellbrook
# ...           ...      ...         ...      ...              ...
# 4686           49       45      Milton     NG22    Rupert Ripple
# 4687           63       54     Marston     ST20    Rupert Ripple
# 4688           59        3      Sutton      RH5    Rupert Ripple
# 4689           46        7  Church End       N3    Rupert Ripple
# 4690            1        1    Charlton     OX12    Rupert Ripple
#
# [4691 rows x 17 columns]

# %%
df_applicant.name = df_applicant.name.str.lower().str.title()

# %%
df_sparta_day[df_sparta_day.duplicated(subset=['name'],keep=False)]
# Out:
#                  name  psychometrics  presentation       date     academy
# 0  Nicolette Bonehill             47            20 2019-11-19      London
# 2   Shurlocke Cringle             52            21 2019-05-21      London
# 1   Shurlocke Cringle             49            18 2019-01-31  Birmingham
# 4  Nicolette Bonehill             52            23 2019-02-05      London

# %%
df_talent[df_talent.name == "Shurlocke Cringle"]
# Out:
#                 name       date  self_development  geo_flex
# 0  Shurlocke Cringle 2019-05-21              True      True  \
#
#    financial_support_self result course_interest json_key
# 0                    True   Pass            Data    12238

# %%
df_talent[df_talent.duplicated(subset=['name','date','result','course_interest'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, date, self_development, geo_flex, financial_support_self, result, course_interest, json_key]
# Index: []

# %%
df_talent = df_talent.drop_duplicates(subset=['name','date','course_interest'],keep='first')

# %%
df_talent[df_talent.name.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, date, self_development, geo_flex, financial_support_self, result, course_interest, json_key]
# Index: []

# %%
df_talent.name.nunique()
# Out:
# 3073

# %%
df_talent[~df_talent.name.isin(df_sparta_day.name)]
# Out:
# Empty DataFrame
# Columns: [name, date, self_development, geo_flex, financial_support_self, result, course_interest, json_key]
# Index: []

# %%
print("\nRecords in Sparta Day:",len(df_sparta_day),
"\nRecords in Talent:",len(df_talent),
"\nNames in Talent that are in Sparta Day:",df_talent.name.isin(df_sparta_day.name).sum(),
"\nUnique names in Talent:", df_talent.name.nunique(),
"\nUnique names in Sparta Day:", df_sparta_day.name.nunique()
)
# Out:
# Records in Sparta Day: 4134
# Records in Talent: 3073
# Names in Talent that are in Sparta Day: 3073
# Unique names in Talent: 3073
# Unique names in Sparta Day: 4132

# %%
len(df_talent)
# Out:
# 3073

# %%
df_temp = pd.merge_asof(df_talent.sort_values('date'),df_sparta_day.sort_values('date'),on='date',by='name')

# %%
df_temp = pd.merge(df_talent,df_sparta_day,on=['name'])

# %%
df_temp[df_temp.date_x != df_temp.date_y]
# Out:
#                      name     date_x  self_development  geo_flex
# 612     Sinclair Breissan 2019-07-12             False      True  \
# 613           Conn Dobson 2019-07-18              True      True
# 614       Nicolle Radford 2019-07-04              True      True
# 615   Marquita Forrington 2019-07-20              True      True
# 616     Ingaborg Pitblado 2019-07-18             False      True
# ...                   ...        ...               ...       ...
# 909          Cleon Kemson 2019-07-20              True      True
# 910         Seymour Rodda 2019-07-06              True      True
# 911           Linc Hallex 2019-07-20              True      True
# 1127   Nicolette Bonehill 2019-02-05             False      True
# 1834    Shurlocke Cringle 2019-05-21              True      True
#
#       financial_support_self result course_interest json_key  psychometrics
# 612                     True   Fail     Engineering    11000             60  \
# 613                    False   Fail        Business    11001             53
# 614                     True   Pass        Business    11002             55
# 615                     True   Pass            Data    11003             60
# 616                     True   Fail        Business    11004             67
# ...                      ...    ...             ...      ...            ...
# 909                     True   Pass     Engineering    11303             59
# 910                    False   Fail     Engineering    11304             54
# 911                     True   Pass     Engineering    11305             50
# 1127                    True   Fail     Engineering    11522             47
# 1834                    True   Pass            Data    12238             49
#
#       presentation     date_y     academy
# 612             19 2019-06-12      London
# 613             20 2019-06-18      London
# 614             22 2019-06-04      London
# 615             17 2019-06-20  Birmingham
# 616             20 2019-06-18      London
# ...            ...        ...         ...
# 909             22 2019-06-20  Birmingham
# 910             20 2019-06-06  Birmingham
# 911             25 2019-06-20  Birmingham
# 1127            20 2019-11-19      London
# 1834            18 2019-01-31  Birmingham
#
# [302 rows x 12 columns]

# %%
df_temp[df_temp.name == 'Shurlocke Cringle']
# Out:
#                    name       date  self_development  geo_flex
# 1150  Shurlocke Cringle 2019-05-21              True      True  \
#
#       financial_support_self result course_interest json_key  psychometrics
# 1150                    True   Pass            Data    12238             52  \
#
#       presentation academy         SpartaDayTalentID
# 1150            21  London  shurlockecringle20190521

# %%
df_sparta_day[df_sparta_day.name == 'Shurlocke Cringle']
# Out:
#                 name  psychometrics  presentation       date     academy
# 2  Shurlocke Cringle             52            21 2019-05-21      London  \
# 1  Shurlocke Cringle             49            18 2019-01-31  Birmingham
#
#           SpartaDayTalentID
# 2  shurlockecringle20190521
# 1  shurlockecringle20190131

# %%
df_talent[~df_talent['name'].isin(df_applicant['name'])]
# Out:
# Empty DataFrame
# Columns: [name, date, self_development, geo_flex, financial_support_self, result, course_interest, json_key]
# Index: []

# %%
df_applicant[~df_applicant['name'].isin(df_talent['name'])]
# Out:
#                   name  gender        dob                        email
# 0       Esme Trusslove  Female 1994-08-04        etrusslove0@google.es  \
# 3          Eryn Speers  Female        NaT       espeers3@shinystat.com
# 4    Theadora Berkelay  Female 1995-11-03       tberkelay4@godaddy.com
# 6       Austina Depper  Female 1992-11-22            adepper6@java.com
# 9      Barbabra Mandal  Female 1991-06-15      bmandal9@craigslist.org
# ..                 ...     ...        ...                          ...
# 411       Rip Jordeson    Male 1994-02-16   rjordesonbf@privacy.gov.au
# 414    Darill Whapples    Male 1999-01-10     dwhapplesbi@hubpages.com
# 417        Kassi Lucio  Female 1994-04-24           kluciobl@exblog.jp
# 418     Vivianna Letty  Female        NaT       vlettybm@google.com.hk
# 419      Mercie Groger  Female 1997-05-10  mgrogerbn@timesonline.co.uk
#
#          phone_number                                                uni
# 0    +44-295-783-0228  Saint George's Hospital Medical School, Univer...  \
# 3    +44-148-787-0613                            University of Edinburgh
# 4    +44-841-468-3619                            University of Leicester
# 6    +44-918-348-8810                               University of Oxford
# 9    +44-723-247-1004                                                NaN
# ..                ...                                                ...
# 411  +44-146-984-9004            University of Wales College of Medicine
# 414  +44-412-578-3310             Birkbeck College, University of London
# 417  +44-834-342-9323                           University of Buckingham
# 418  +44-534-758-3140                      Leeds Metropolitan University
# 419  +44-662-239-4688                             ifs University College
#
#     degree invited_date    iddate              applicant_id  recruiter_id
# 0      2:1   2019-04-10  20190410     esmetrusslove20190410             1
# 3      2:1          NaT  20190400        erynspeers20190400             4
# 4      2:1   2019-04-02  20190402  theadoraberkelay20190402             5
# 6      3rd   2019-04-02  20190402     austinadepper20190402             5
# 9      NaN   2019-04-23  20190423    barbabramandal20190423             3
# ..     ...          ...       ...                       ...           ...
# 411    2:2   2019-09-25  20190925       ripjordeson20190925             8
# 414    1st   2019-09-19  20190919    darillwhapples20190919             7
# 417    2:1   2019-09-03  20190903        kassilucio20190903             6
# 418    1st   2019-09-19  20190919     viviannaletty20190919             1
# 419    3rd   2019-09-12  20190912      merciegroger20190912             8
#
# [1616 rows x 11 columns]

# %%
print(len(df_applicant) - len(df_talent))
# Out:
# 1618

# %%
df_applicant[df_applicant.name.duplicated(keep=False)]
# Out:
#                   name  gender        dob                     email
# 52  Nicolette Bonehill  Female 1995-04-05  nbonehill1g@hubpages.com  \
# 8    Shurlocke Cringle    Male 1992-04-16      scringle8@uol.com.br
# 15   Shurlocke Cringle    Male 1995-11-27                       NaN
# 9   Nicolette Bonehill  Female 1999-08-14       neebee9@addthis.com
#
#         phone_number                      uni degree invited_date    iddate
# 52  +44-825-679-5108     University of Oxford    3rd   2019-02-05  20190205  \
# 8                NaN    South Bank University    3rd   2019-01-31  20190131
# 15  +44-947-829-3817  University of Leicester    2:2   2019-05-21  20190521
# 9   +44-364-359-2606     Cranfield University    2:1   2019-11-19  20191119
#
#                  applicant_id  recruiter_id
# 52  nicolettebonehill20190205             5
# 8    shurlockecringle20190131             8
# 15   shurlockecringle20190521             8
# 9   nicolettebonehill20191119             8

# %%
df_talent[df_talent.name == "Nicolette Bonehill"]
# Out:
#                  name       date  self_development  geo_flex
# 0  Nicolette Bonehill 2019-02-05             False      True  \
#
#    financial_support_self result course_interest json_key
# 0                    True   Fail     Engineering    11522

# %%
df_sparta_day[df_sparta_day.name == "Nicolette Bonehill"]
# Out:
#                  name  psychometrics  presentation       date academy
# 0  Nicolette Bonehill             47            20 2019-11-19  London  \
# 4  Nicolette Bonehill             52            23 2019-02-05  London
#
#            SpartaDayTalentID
# 0  nicolettebonehill20191119
# 4  nicolettebonehill20190205

# %%
len(df_sparta_day)
# Out:
# 4134

# %%
len(df_applicant)
# Out:
# 4691

# %%
df_applicant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4691 entries, 0 to 419
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          4691 non-null   object
#  1   gender        4558 non-null   object
#  2   dob           4458 non-null   datetime64[ns]
#  3   email         4420 non-null   object
#  4   phone_number  4309 non-null   object
#  5   uni           4528 non-null   object
#  6   degree        4528 non-null   object
#  7   invited_date  4134 non-null   datetime64[ns]
#  8   iddate        4691 non-null   object
#  9   applicant_id  4691 non-null   object
#  10  recruiter_id  4691 non-null   int64
# dtypes: datetime64[ns](2), int64(1), object(8)
# memory usage: 439.8+ KB

# %%
pd.merge(df_applicant,df_talent,left_on=['name','invited_date'],right_on=['name','date'])
# Out:
#                   name  gender        dob                       email
# 0      Matthaeus Audas    Male        NaT        maudas1@mapquest.com  \
# 1      Cherey Tollfree  Female 1992-12-08     ctollfree2@netvibes.com
# 2        Kassi Pinnock  Female 1990-04-19        kpinnock5@apache.org
# 3          Rivi Epinay  Female 1992-02-12       repinay7@blogspot.com
# 4         Lay Trosdall    Male 1991-07-05    ltrosdall8@imageshack.us
# ...                ...     ...        ...                         ...
# 2768     Arman Boribal    Male 1999-05-07  aboribalbe@hugedomains.com
# 2769   Vernon Bennough    Male 1996-05-13                         NaN
# 2770  Monty Gorriessen    Male 1995-03-24                         NaN
# 2771   Clyve Gillhespy    Male 1995-12-15   cgillhespybj@buzzfeed.com
# 2772   Vaclav Pietesch    Male 1994-11-09         vpieteschbk@mac.com
#
#           phone_number                                          uni degree
# 0     +44-957-728-0155                             Keele University    2:1  \
# 1     +44-588-749-6002  King's College London, University of London    2:1
# 2     +44-897-978-7574            The American University in London    1st
# 3     +44-674-101-0656                   Trinity College Carmarthen    1st
# 4     +44-572-951-7038                                          NaN    NaN
# ...                ...                                          ...    ...
# 2768               NaN                   Trinity College Carmarthen    1st
# 2769  +44-655-174-5869                      University of Cambridge    2:1
# 2770  +44-681-641-4060    International Colleges of Islamic Science    2:1
# 2771  +44-904-343-2218                      University of Liverpool    2:1
# 2772  +44-455-631-6125                  Sheffield Hallam University    2:2
#
#      invited_date    iddate             applicant_id  recruiter_id       date
# 0      2019-04-30  20190430   matthaeusaudas20190430             2 2019-04-30  \
# 1      2019-04-25  20190425   chereytollfree20190425             3 2019-04-25
# 2      2019-04-18  20190418     kassipinnock20190418             3 2019-04-18
# 3      2019-04-17  20190417       riviepinay20190417             6 2019-04-17
# 4      2019-04-16  20190416      laytrosdall20190416             1 2019-04-16
# ...           ...       ...                      ...           ...        ...
# 2768   2019-09-04  20190904     armanboribal20190904             8 2019-09-04
# 2769   2019-09-24  20190924   vernonbennough20190924             6 2019-09-24
# 2770   2019-09-12  20190912  montygorriessen20190912             6 2019-09-12
# 2771   2019-09-26  20190926   clyvegillhespy20190926             1 2019-09-26
# 2772   2019-09-12  20190912   vaclavpietesch20190912             5 2019-09-12
#
#       self_development  geo_flex  financial_support_self result
# 0                 True      True                    True   Pass  \
# 1                 True      True                    True   Pass
# 2                 True      True                    True   Pass
# 3                 True     False                    True   Fail
# 4                 True      True                    True   Pass
# ...                ...       ...                     ...    ...
# 2768              True      True                    True   Pass
# 2769              True      True                    True   Pass
# 2770              True      True                    True   Pass
# 2771              True      True                    True   Pass
# 2772              True      True                   False   Fail
#
#      course_interest json_key
# 0               Data    13231
# 1           Business    13232
# 2        Engineering    13233
# 3           Business    13234
# 4        Engineering    13235
# ...              ...      ...
# 2768            Data    13226
# 2769     Engineering    13227
# 2770            Data    13228
# 2771        Business    13229
# 2772     Engineering    13230
#
# [2773 rows x 18 columns]

# %%
print(len(df_applicant),len(df_sparta_day))
# Out:
# 4691 4134

# %%
df_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4691 entries, 0 to 419
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       4597 non-null   object
#  1   postcode      4597 non-null   object
#  2   city          4597 non-null   object
#  3   applicant_id  4691 non-null   object
#  4   location_id   4691 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 219.9+ KB

# %%
df_address[df_address.address.duplicated(keep=False)].sort_values('address')
# Out:
#               address postcode     city               applicant_id
# 253    3 Crowley Hill     PH43  Kinloch    hendrickskellon20191218  \
# 378    3 Crowley Hill      PR1  Preston        neelcampana20190925
# 187     4 Harper Park     NG22   Milton     allegraaspland20190102
# 394     4 Harper Park      IV1   Newton  corbycristofolini20191015
# 220  4 Homewood Trail      LS6    Leeds       giselaandrea20191029
# ..                ...      ...      ...                        ...
# 349               NaN      NaN      NaN       godivaandrew20191009
# 355               NaN      NaN      NaN   janosshellsheere20191030
# 11                NaN      NaN      NaN      rickieburkert20190925
# 149               NaN      NaN      NaN      yorgosdockery20190903
# 296               NaN      NaN      NaN       rikkirowlett20190900
#
#      location_id
# 253         1085
# 378         4649
# 187         1676
# 394         4266
# 220         4092
# ..           ...
# 349         4221
# 355         4227
# 11          4282
# 149         4420
# 296         4567
#
# [106 rows x 5 columns]

# %%
pd.merge(df_applicant,df_sparta_day,left_on=['name','invited_date'],right_on=['name','date'],how='inner')
# Out:
#                    name  gender        dob                        email
# 0        Esme Trusslove  Female 1994-08-04        etrusslove0@google.es  \
# 1       Matthaeus Audas    Male        NaT         maudas1@mapquest.com
# 2       Cherey Tollfree  Female 1992-12-08      ctollfree2@netvibes.com
# 3     Theadora Berkelay  Female 1995-11-03       tberkelay4@godaddy.com
# 4         Kassi Pinnock  Female 1990-04-19         kpinnock5@apache.org
# ...                 ...     ...        ...                          ...
# 4129    Clyve Gillhespy    Male 1995-12-15    cgillhespybj@buzzfeed.com
# 4130    Vaclav Pietesch    Male 1994-11-09          vpieteschbk@mac.com
# 4131        Kassi Lucio  Female 1994-04-24           kluciobl@exblog.jp
# 4132     Vivianna Letty  Female        NaT       vlettybm@google.com.hk
# 4133      Mercie Groger  Female 1997-05-10  mgrogerbn@timesonline.co.uk
#
#           phone_number                                                uni
# 0     +44-295-783-0228  Saint George's Hospital Medical School, Univer...  \
# 1     +44-957-728-0155                                   Keele University
# 2     +44-588-749-6002        King's College London, University of London
# 3     +44-841-468-3619                            University of Leicester
# 4     +44-897-978-7574                  The American University in London
# ...                ...                                                ...
# 4129  +44-904-343-2218                            University of Liverpool
# 4130  +44-455-631-6125                        Sheffield Hallam University
# 4131  +44-834-342-9323                           University of Buckingham
# 4132  +44-534-758-3140                      Leeds Metropolitan University
# 4133  +44-662-239-4688                             ifs University College
#
#      degree invited_date    iddate              applicant_id  recruiter_id
# 0       2:1   2019-04-10  20190410     esmetrusslove20190410             1  \
# 1       2:1   2019-04-30  20190430    matthaeusaudas20190430             2
# 2       2:1   2019-04-25  20190425    chereytollfree20190425             3
# 3       2:1   2019-04-02  20190402  theadoraberkelay20190402             5
# 4       1st   2019-04-18  20190418      kassipinnock20190418             3
# ...     ...          ...       ...                       ...           ...
# 4129    2:1   2019-09-26  20190926    clyvegillhespy20190926             1
# 4130    2:2   2019-09-12  20190912    vaclavpietesch20190912             5
# 4131    2:1   2019-09-03  20190903        kassilucio20190903             6
# 4132    1st   2019-09-19  20190919     viviannaletty20190919             1
# 4133    3rd   2019-09-12  20190912      merciegroger20190912             8
#
#       psychometrics  presentation       date     academy
# 0                39            23 2019-04-10      London
# 1                59            20 2019-04-30      London
# 2                59            18 2019-04-25  Birmingham
# 3                59            12 2019-04-02      London
# 4                63            15 2019-04-18  Birmingham
# ...             ...           ...        ...         ...
# 4129             59            24 2019-09-26  Birmingham
# 4130             61            27 2019-09-12  Birmingham
# 4131             60            24 2019-09-03      London
# 4132             56            19 2019-09-19  Birmingham
# 4133             43            24 2019-09-12  Birmingham
#
# [4134 rows x 15 columns]
