# %%
# I want to combine the 3 academy raw files into one file 
import boto3
import pandas as pd
s3 = boto3.client('s3')
bucket_name = 'data-eng-210-final-project'
folder_name = 'Academy'

# %%
objects = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_name)

# %%
dfs = []
for obj in objects['Contents']:
    key = obj['Key']
    if key.endswith('.csv'):
        obj = s3.get_object(Bucket=bucket_name, Key=key)
        df = pd.read_csv(obj['Body'])
        dfs.append(df)

# %%
# concatenate all dataframes into a single dataframe
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df
# Out:
#                 name             trainer  Analytic_W1  Independent_W1
# 0    Quintus Penella        Gregor Gomez            1               2  \
# 1       Simon Murrey        Gregor Gomez            6               1
# 2        Gustaf Lude        Gregor Gomez            6               4
# 3      Yolanda Fosse        Gregor Gomez            2               1
# 4       Lynnett Swin        Gregor Gomez            2               2
# ..               ...                 ...          ...             ...
# 392  Moritz Mosedall  Mohammad Velazquez            1               1
# 393     Chaim Inseal  Mohammad Velazquez            1               3
# 394  Gertruda Syddie  Mohammad Velazquez            3               1
# 395      Thom Derwin  Mohammad Velazquez            3               7
# 396   Godfry Sephton  Mohammad Velazquez            4               2
#
#      Determined_W1  Professional_W1  Studious_W1  Imaginative_W1  Analytic_W2
# 0                2                1            2               2          NaN  \
# 1                1                2            4               2          3.0
# 2                1                1            2               3          1.0
# 3                2                3            3               3          4.0
# 4                4                5            1               2          3.0
# ..             ...              ...          ...             ...          ...
# 392              5                1            2               6          5.0
# 393              3                4            1               2          3.0
# 394              2                8            1               4          2.0
# 395              3                3            3               1          2.0
# 396              5                1            1               2          4.0
#
#      Independent_W2  ...  Determined_W9  Professional_W9  Studious_W9
# 0               NaN  ...            NaN              NaN          NaN  \
# 1               1.0  ...            NaN              NaN          NaN
# 2               1.0  ...            NaN              NaN          NaN
# 3               2.0  ...            NaN              NaN          NaN
# 4               2.0  ...            NaN              NaN          NaN
# ..              ...  ...            ...              ...          ...
# 392             3.0  ...            NaN              NaN          NaN
# 393             3.0  ...            NaN              NaN          NaN
# 394             4.0  ...            NaN              NaN          NaN
# 395             7.0  ...            NaN              NaN          NaN
# 396             1.0  ...            NaN              NaN          NaN
#
#      Imaginative_W9  Analytic_W10  Independent_W10  Determined_W10
# 0               NaN           NaN              NaN             NaN  \
# 1               NaN           NaN              NaN             NaN
# 2               NaN           NaN              NaN             NaN
# 3               NaN           NaN              NaN             NaN
# 4               NaN           NaN              NaN             NaN
# ..              ...           ...              ...             ...
# 392             NaN           NaN              NaN             NaN
# 393             NaN           NaN              NaN             NaN
# 394             NaN           NaN              NaN             NaN
# 395             NaN           NaN              NaN             NaN
# 396             NaN           NaN              NaN             NaN
#
#      Professional_W10  Studious_W10  Imaginative_W10
# 0                 NaN           NaN              NaN
# 1                 NaN           NaN              NaN
# 2                 NaN           NaN              NaN
# 3                 NaN           NaN              NaN
# 4                 NaN           NaN              NaN
# ..                ...           ...              ...
# 392               NaN           NaN              NaN
# 393               NaN           NaN              NaN
# 394               NaN           NaN              NaN
# 395               NaN           NaN              NaN
# 396               NaN           NaN              NaN
#
# [397 rows x 62 columns]

# %%
print(combined_df.head())
# Out:
#               name       trainer  Analytic_W1  Independent_W1  Determined_W1
# 0  Quintus Penella  Gregor Gomez            1               2              2  \
# 1     Simon Murrey  Gregor Gomez            6               1              1
# 2      Gustaf Lude  Gregor Gomez            6               4              1
# 3    Yolanda Fosse  Gregor Gomez            2               1              2
# 4     Lynnett Swin  Gregor Gomez            2               2              4
#
#    Professional_W1  Studious_W1  Imaginative_W1  Analytic_W2  Independent_W2
# 0                1            2               2          NaN             NaN  \
# 1                2            4               2          3.0             1.0
# 2                1            2               3          1.0             1.0
# 3                3            3               3          4.0             2.0
# 4                5            1               2          3.0             2.0
#
#    ...  Determined_W9  Professional_W9  Studious_W9  Imaginative_W9
# 0  ...            NaN              NaN          NaN             NaN  \
# 1  ...            NaN              NaN          NaN             NaN
# 2  ...            NaN              NaN          NaN             NaN
# 3  ...            NaN              NaN          NaN             NaN
# 4  ...            NaN              NaN          NaN             NaN
#
#    Analytic_W10  Independent_W10  Determined_W10  Professional_W10
# 0           NaN              NaN             NaN               NaN  \
# 1           NaN              NaN             NaN               NaN
# 2           NaN              NaN             NaN               NaN
# 3           NaN              NaN             NaN               NaN
# 4           NaN              NaN             NaN               NaN
#
#    Studious_W10  Imaginative_W10
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
#
# [5 rows x 62 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 62 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              397 non-null    object
#  1   trainer           397 non-null    object
#  2   Analytic_W1       397 non-null    int64
#  3   Independent_W1    397 non-null    int64
#  4   Determined_W1     397 non-null    int64
#  5   Professional_W1   397 non-null    int64
#  6   Studious_W1       397 non-null    int64
#  7   Imaginative_W1    397 non-null    int64
#  8   Analytic_W2       387 non-null    float64
#  9   Independent_W2    387 non-null    float64
#  10  Determined_W2     387 non-null    float64
#  11  Professional_W2   387 non-null    float64
#  12  Studious_W2       387 non-null    float64
#  13  Imaginative_W2    387 non-null    float64
#  14  Analytic_W3       369 non-null    float64
#  15  Independent_W3    369 non-null    float64
#  16  Determined_W3     369 non-null    float64
#  17  Professional_W3   369 non-null    float64
#  18  Studious_W3       369 non-null    float64
#  19  Imaginative_W3    369 non-null    float64
#  20  Analytic_W4       356 non-null    float64
#  21  Independent_W4    356 non-null    float64
#  22  Determined_W4     356 non-null    float64
#  23  Professional_W4   356 non-null    float64
#  24  Studious_W4       356 non-null    float64
#  25  Imaginative_W4    356 non-null    float64
#  26  Analytic_W5       356 non-null    float64
#  27  Independent_W5    356 non-null    float64
#  28  Determined_W5     356 non-null    float64
#  29  Professional_W5   356 non-null    float64
#  30  Studious_W5       356 non-null    float64
#  31  Imaginative_W5    356 non-null    float64
#  32  Analytic_W6       356 non-null    float64
#  33  Independent_W6    356 non-null    float64
#  34  Determined_W6     356 non-null    float64
#  35  Professional_W6   356 non-null    float64
#  36  Studious_W6       356 non-null    float64
#  37  Imaginative_W6    356 non-null    float64
#  38  Analytic_W7       356 non-null    float64
#  39  Independent_W7    356 non-null    float64
#  40  Determined_W7     356 non-null    float64
#  41  Professional_W7   356 non-null    float64
#  42  Studious_W7       356 non-null    float64
#  43  Imaginative_W7    356 non-null    float64
#  44  Analytic_W8       356 non-null    float64
#  45  Independent_W8    356 non-null    float64
#  46  Determined_W8     356 non-null    float64
#  47  Professional_W8   356 non-null    float64
#  48  Studious_W8       356 non-null    float64
#  49  Imaginative_W8    356 non-null    float64
#  50  Analytic_W9       162 non-null    float64
#  51  Independent_W9    162 non-null    float64
#  52  Determined_W9     162 non-null    float64
#  53  Professional_W9   162 non-null    float64
#  54  Studious_W9       162 non-null    float64
#  55  Imaginative_W9    162 non-null    float64
#  56  Analytic_W10      162 non-null    float64
#  57  Independent_W10   162 non-null    float64
#  58  Determined_W10    162 non-null    float64
#  59  Professional_W10  162 non-null    float64
#  60  Studious_W10      162 non-null    float64
#  61  Imaginative_W10   162 non-null    float64
# dtypes: float64(54), int64(6), object(2)
# memory usage: 192.4+ KB

# %%
# Calculate the number of null values per column
null_values_count = combined_df.isnull().sum()

# Calculate the percentage of null values per column
null_values_percentage = (null_values_count / len(combined_df)) * 100

# Combine the counts and percentages into a single DataFrame
null_values_summary = pd.DataFrame({
    'Null Values Count': null_values_count,
    'Null Values Percentage': null_values_percentage
})

# Display the summary DataFrame
print(null_values_summary)
# Out:
#                   Null Values Count  Null Values Percentage
# name                              0                0.000000
# trainer                           0                0.000000
# Analytic_W1                       0                0.000000
# Independent_W1                    0                0.000000
# Determined_W1                     0                0.000000
# ...                             ...                     ...
# Independent_W10                 235               59.193955
# Determined_W10                  235               59.193955
# Professional_W10                235               59.193955
# Studious_W10                    235               59.193955
# Imaginative_W10                 235               59.193955
#
# [62 rows x 2 columns]

# %%
#see if we have duplicate names
duplicate_rows = combined_df[combined_df['name'].duplicated()]
duplicate_names = duplicate_rows['name'].unique()

print("Duplicate names:", list(duplicate_names))
# Out:
# Duplicate names: []

# %%
# change name and trainer in lower cases
combined_df['name'] = combined_df['name'].str.lower()
combined_df['trainer'] = combined_df['trainer'].str.lower()

# %%
#change columns to be in lower case
combined_df.columns = [col.lower() for col in combined_df.columns]

# %%
#to remove.0 from our values
cols_to_convert = [col for col in combined_df.columns if col.startswith(('analytic_', 'independent_', 'determined_', 'professional_', 'studious_', 'imaginative_'))]

combined_df[cols_to_convert] = combined_df[cols_to_convert].astype(str).apply(lambda x: x.str.split('.').str[0])

# %%
combined_df
# Out:
#                 name             trainer analytic_w1 independent_w1
# 0    quintus penella        gregor gomez           1              2  \
# 1       simon murrey        gregor gomez           6              1
# 2        gustaf lude        gregor gomez           6              4
# 3      yolanda fosse        gregor gomez           2              1
# 4       lynnett swin        gregor gomez           2              2
# ..               ...                 ...         ...            ...
# 392  moritz mosedall  mohammad velazquez           1              1
# 393     chaim inseal  mohammad velazquez           1              3
# 394  gertruda syddie  mohammad velazquez           3              1
# 395      thom derwin  mohammad velazquez           3              7
# 396   godfry sephton  mohammad velazquez           4              2
#
#     determined_w1 professional_w1 studious_w1 imaginative_w1 analytic_w2
# 0               2               1           2              2         nan  \
# 1               1               2           4              2           3
# 2               1               1           2              3           1
# 3               2               3           3              3           4
# 4               4               5           1              2           3
# ..            ...             ...         ...            ...         ...
# 392             5               1           2              6           5
# 393             3               4           1              2           3
# 394             2               8           1              4           2
# 395             3               3           3              1           2
# 396             5               1           1              2           4
#
#     independent_w2  ... determined_w9 professional_w9 studious_w9
# 0              nan  ...           nan             nan         nan  \
# 1                1  ...           nan             nan         nan
# 2                1  ...           nan             nan         nan
# 3                2  ...           nan             nan         nan
# 4                2  ...           nan             nan         nan
# ..             ...  ...           ...             ...         ...
# 392              3  ...           nan             nan         nan
# 393              3  ...           nan             nan         nan
# 394              4  ...           nan             nan         nan
# 395              7  ...           nan             nan         nan
# 396              1  ...           nan             nan         nan
#
#     imaginative_w9 analytic_w10 independent_w10 determined_w10
# 0              nan          nan             nan            nan  \
# 1              nan          nan             nan            nan
# 2              nan          nan             nan            nan
# 3              nan          nan             nan            nan
# 4              nan          nan             nan            nan
# ..             ...          ...             ...            ...
# 392            nan          nan             nan            nan
# 393            nan          nan             nan            nan
# 394            nan          nan             nan            nan
# 395            nan          nan             nan            nan
# 396            nan          nan             nan            nan
#
#     professional_w10 studious_w10 imaginative_w10
# 0                nan          nan             nan
# 1                nan          nan             nan
# 2                nan          nan             nan
# 3                nan          nan             nan
# 4                nan          nan             nan
# ..               ...          ...             ...
# 392              nan          nan             nan
# 393              nan          nan             nan
# 394              nan          nan             nan
# 395              nan          nan             nan
# 396              nan          nan             nan
#
# [397 rows x 62 columns]
